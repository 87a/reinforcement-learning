# %%
from maze import ShortcutMazeEnv
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
env = ShortcutMazeEnv()
done, state = False, env.reset()
env.render()
while not done:
    action = np.random.choice(env.action_space.n)
    state, reward, done, info = env.step(action)
    env.render()
